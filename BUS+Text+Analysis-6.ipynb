# %%
#Chirag Narayanakere

from urllib.request import urlopen
import json
import pandas as pd
from pandas.io.json import json_normalize

#this is the url that we've already determined is safe and legal to scrape from
request = 'http://api.crossref.org/journals/00222429/works?filter=from-pub-date:2000-01-01&select=DOI&rows=1000'
request2 = 'http://api.crossref.org/journals/00222429/works?filter=from-pub-date:2000-01-01&select=DOI&rows=1000&offset=1000'

#here, we fetch the content from the url, using the requests library
response = urlopen(request, timeout=5)
response2 = urlopen(request2, timeout=5)

#here, we store the response (as a json object)
dois = response.read()
dois2 = response2.read()

#here, we read the json object into a dictionary
test = pandas.read_json(dois)
test2 = pandas.read_json(dois2)

#here, we convert the dictionary to a dataframe to allow for easier manipulation
master = pd.DataFrame.from_dict(test.iloc[1, 0])
master2 = pd.DataFrame.from_dict(test2.iloc[1, 0])

#combined dataframe
master_final = pd.concat([master, master2]).reset_index(drop=True)

#adding the base url to all the doi values
for i in range(0, len(master_final)):
    master_final['DOI'][i] = "https://journals.sagepub.com/doi/pdf/" + master_final['DOI'][i]

#show entire output
pd.set_option('display.max_colwidth', -1)

#final dataframe
master_final
# Out:
#                                                                    DOI
# 0     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.67.2.123.18610
# 1     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.35
# 2     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.18
# 3     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.6.119
# 4     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.5.80
# 5     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.66.4.57.18512
# 6     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.3.131.66359
# 7     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.1.114.55514
# 8     https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0599
# 9     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.1.24
# 10    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.4.36
# 11    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.18
# 12    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.75.2.18
# 13    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.4.1
# 14    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.75.4.35
# 15    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.5.50
# 16    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.75.2.93
# 17    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.3.19.66363
# 18    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.66.1.73.18450
# 19    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.68.4.1.42733
# 20    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.2005.69.4.84
# 21    https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0105
# 22    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.2.71
# 23    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.66.1.38.18451
# 24    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.4.154
# 25    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.3.35.66357
# 26    https://journals.sagepub.com/doi/pdf/10.1509/jm.13.0509
# 27    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.3.1.66358
# 28    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.3.52
# 29    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.65.3.79.18329
# ...                                                               ...
# 1003  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.5.30
# 1004  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.6.19
# 1005  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.66.3.1.18505
# 1006  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.2005.69.4.61
# 1007  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.3.14
# 1008  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.4.90
# 1009  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.1.1
# 1010  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.5.32
# 1011  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.2006.70.1.137
# 1012  https://journals.sagepub.com/doi/pdf/10.1509/jm.10.0537
# 1013  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.3.74
# 1014  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.2005.69.4.167
# 1015  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.67.2.76.18609
# 1016  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.67.4.30.18685
# 1017  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.5.90
# 1018  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.2005.69.4.252
# 1019  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.68.1.1.24036
# 1020  https://journals.sagepub.com/doi/pdf/10.1509/jm.10.0418
# 1021  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.2.24.60761
# 1022  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.68.1.90.24028
# 1023  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.2006.70.1.119
# 1024  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.3.1
# 1025  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.2.20
# 1026  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.67.2.35.18612
# 1027  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.75.4.136
# 1028  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.1.1
# 1029  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.6.1
# 1030  https://journals.sagepub.com/doi/pdf/10.1509/jm.15.0420
# 1031  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.2.99
# 1032  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.67.4.1.18688
#
# [1033 rows x 1 columns]

# %% [markdown]
# ## Have to split up the status code checking into multiple parts so system does not time out

# %%
import requests

#holds indices of articles that do no exist anymore
errors = []

for i in range(0, 200):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors.append(i)

#print error links        
print(errors)

# %%
import requests

#holds indices of articles that do no exist anymore
errors1 = []

for i in range(200, 400):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors1.append(i)
        
print(errors1)
# Out:
# [265, 266, 267, 268, 269, 270, 272, 273, 275, 276, 277, 278, 282, 284, 287, 288]

# %%
import requests

#holds indices of articles that do no exist anymore
errors2 = []

for i in range(400, 600):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors2.append(i)

print(errors2)
# Out:
# [427, 513, 516, 520, 525, 526, 527, 537, 543, 556, 562, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 586, 587, 590, 593, 596, 597, 598, 599]

# %%
import requests

#holds indices of articles that do no exist anymore
errors3 = []

for i in range(600, 800):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors3.append(i)

print(errors3)
# Out:
# [600, 601, 603, 604, 605, 607, 608, 609, 610, 611, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 626, 627, 628, 631, 632, 637, 639, 640, 642, 643, 644, 645, 646, 647, 648, 649, 650, 651, 653, 655, 656, 657, 658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 683, 684, 685, 687, 688, 689, 690, 691, 692, 694, 695, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 709, 711, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 770]

# %%
import requests

#holds indices of articles that do no exist anymore
errors4 = []

for i in range(800, 1000):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors4.append(i)

print(errors4)
# Out:
# [808, 815, 817, 820, 821, 833, 835, 837, 852, 871, 876, 877, 878, 879, 881, 888, 893, 901, 902, 908, 921, 930, 931, 945, 981, 983, 989, 990, 991, 994]

# %%
import requests

#holds indices of articles that do no exist anymore
errors5 = []

for i in range(1000, 1033):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors5.append(i)

print(errors5)
# Out:
# [1004, 1007, 1008, 1009, 1010, 1011, 1013, 1023, 1024, 1025]
