# %%
#Chirag Narayanakere

from urllib.request import urlopen
import json
import pandas as pd
from pandas.io.json import json_normalize

#this is the url that we've already determined is safe and legal to scrape from
request = 'http://api.crossref.org/journals/00222429/works?filter=from-pub-date:2000-01-01&select=DOI&rows=1000'
request2 = 'http://api.crossref.org/journals/00222429/works?filter=from-pub-date:2000-01-01&select=DOI&rows=1000&offset=1000'

#here, we fetch the content from the url, using the requests library
response = urlopen(request, timeout=5)
response2 = urlopen(request2, timeout=5)

#here, we store the response (as a json object)
dois = response.read()
dois2 = response2.read()

#here, we read the json object into a dictionary
test = pd.read_json(dois)
test2 = pd.read_json(dois2)

#here, we convert the dictionary to a dataframe to allow for easier manipulation
master = pd.DataFrame.from_dict(test.iloc[1, 0])
master2 = pd.DataFrame.from_dict(test2.iloc[1, 0])

#combined dataframe
master_final = pd.concat([master, master2]).reset_index(drop=True)

#adding the base url to all the doi values
for i in range(0, len(master_final)):
    master_final['DOI'][i] = "https://journals.sagepub.com/doi/pdf/" + master_final['DOI'][i]

#show entire output
pd.set_option('display.max_colwidth', -1)

#final dataframe
master_final
# Out:
#                                                                  DOI
# 0     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.3.1.66358
# 1     https://journals.sagepub.com/doi/pdf/10.1509/jm.17.0276
# 2     https://journals.sagepub.com/doi/pdf/10.1509/jm.17.0100
# 3     https://journals.sagepub.com/doi/pdf/10.1509/jm.17.0328
# 4     https://journals.sagepub.com/doi/pdf/10.1177/0022242918812056
# 5     https://journals.sagepub.com/doi/pdf/10.1177/0022242918812055
# 6     https://journals.sagepub.com/doi/pdf/10.1177/0022242918814254
# 7     https://journals.sagepub.com/doi/pdf/10.1177/0022242918815895
# 8     https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0276
# 9     https://journals.sagepub.com/doi/pdf/10.1177/0022242918805485
# 10    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805455
# 11    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805059
# 12    https://journals.sagepub.com/doi/pdf/10.1177/0022242918807170
# 13    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805468
# 14    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805405
# 15    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805411
# 16    https://journals.sagepub.com/doi/pdf/10.1177/0022242918815894
# 17    https://journals.sagepub.com/doi/pdf/10.1177/0022242918807673
# 18    https://journals.sagepub.com/doi/pdf/10.1177/0022242918809380
# 19    https://journals.sagepub.com/doi/pdf/10.1177/0022242918818404
# 20    https://journals.sagepub.com/doi/pdf/10.1177/0022242918815880
# 21    https://journals.sagepub.com/doi/pdf/10.1177/0022242918816319
# 22    https://journals.sagepub.com/doi/pdf/10.1177/0022242918799699
# 23    https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0560
# 24    https://journals.sagepub.com/doi/pdf/10.1509/jm.09.0209
# 25    https://journals.sagepub.com/doi/pdf/10.1509/jm.10.0205
# 26    https://journals.sagepub.com/doi/pdf/10.1509/jm.09.0034
# 27    https://journals.sagepub.com/doi/pdf/10.1509/jm.10.0400
# 28    https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0400
# 29    https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0428
# ...                                                       ...
# 1181  https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0311
# 1182  https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0113
# 1183  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.65
# 1184  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.3.074
# 1185  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.016
# 1186  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.4.1
# 1187  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.1
# 1188  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.080
# 1189  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.65
# 1190  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.6.19
# 1191  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.5.1
# 1192  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.80
# 1193  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.1.035
# 1194  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.3.74
# 1195  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.5.98
# 1196  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.4.15
# 1197  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.065
# 1198  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.3.052
# 1199  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.1.24
# 1200  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.1.35
# 1201  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.48
# 1202  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.6.019
# 1203  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.4.031
# 1204  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.001
# 1205  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.018
# 1206  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.4.001
# 1207  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.3.021
# 1208  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.065
# 1209  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.3.048
# 1210  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.16
#
# [1211 rows x 1 columns]

# %% [markdown]
# ## Have to split up the status code checking into multiple parts so system does not time out

# %%
import requests

#holds indices of articles that do no exist anymore
errors = []

for i in range(0, 200):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors.append(i)

#print error links        
print(errors)
# Out:
# [83, 84, 94, 97, 98, 99, 107, 108, 109, 110, 111, 113, 114, 115, 116, 117, 118, 119, 164, 168, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 188, 189, 190, 191, 192, 193, 195, 196, 197, 198, 199]

# %%
import requests

#holds indices of articles that do no exist anymore
errors1 = []

for i in range(200, 400):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors1.append(i)
        
print(errors1)
# Out:
# [200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 343, 344]

# %%
import requests

#holds indices of articles that do no exist anymore
errors2 = []

for i in range(400, 600):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors2.append(i)

print(errors2)
# Out:
# [405, 410, 415, 417, 423, 426, 427, 429, 431, 481, 482, 485, 487, 488, 490, 491, 492, 494, 496, 498, 499]

# %%
import requests

#holds indices of articles that do no exist anymore
errors3 = []

for i in range(600, 800):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors3.append(i)

print(errors3)
# Out:
# [605, 606, 609, 613, 615, 620, 622, 629, 633, 684, 687, 692, 693, 696, 699, 700, 701, 706, 710, 714, 718, 719, 721, 727, 774, 775, 778, 783]

# %%
import requests

#holds indices of articles that do no exist anymore
errors4 = []

for i in range(800, 1000):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors4.append(i)

print(errors4)
# Out:
# [802, 803, 804, 805, 809, 834, 839, 840, 841, 842, 861, 958, 962, 963, 966, 967, 998, 999]

# %%
import requests

#holds indices of articles that do no exist anymore
errors5 = []

for i in range(1000, 1033):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors5.append(i)

print(errors5)
# Out:
# [1001, 1004, 1011, 1012, 1013, 1015, 1019, 1023, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032]

# %%
#dropping rows where status code == 404
master_final_filtered = master_final.drop(errors)
master_final_filtered = master_final_filtered.drop(errors1)
master_final_filtered = master_final_filtered.drop(errors2)
master_final_filtered = master_final_filtered.drop(errors3)
master_final_filtered = master_final_filtered.drop(errors4)
master_final_filtered = master_final_filtered.drop(errors5)

#final dataframe post filtration
master_final_filtered
# Out:
#                                                                  DOI
# 0     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.69.3.1.66358
# 1     https://journals.sagepub.com/doi/pdf/10.1509/jm.17.0276
# 2     https://journals.sagepub.com/doi/pdf/10.1509/jm.17.0100
# 3     https://journals.sagepub.com/doi/pdf/10.1509/jm.17.0328
# 4     https://journals.sagepub.com/doi/pdf/10.1177/0022242918812056
# 5     https://journals.sagepub.com/doi/pdf/10.1177/0022242918812055
# 6     https://journals.sagepub.com/doi/pdf/10.1177/0022242918814254
# 7     https://journals.sagepub.com/doi/pdf/10.1177/0022242918815895
# 8     https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0276
# 9     https://journals.sagepub.com/doi/pdf/10.1177/0022242918805485
# 10    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805455
# 11    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805059
# 12    https://journals.sagepub.com/doi/pdf/10.1177/0022242918807170
# 13    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805468
# 14    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805405
# 15    https://journals.sagepub.com/doi/pdf/10.1177/0022242918805411
# 16    https://journals.sagepub.com/doi/pdf/10.1177/0022242918815894
# 17    https://journals.sagepub.com/doi/pdf/10.1177/0022242918807673
# 18    https://journals.sagepub.com/doi/pdf/10.1177/0022242918809380
# 19    https://journals.sagepub.com/doi/pdf/10.1177/0022242918818404
# 20    https://journals.sagepub.com/doi/pdf/10.1177/0022242918815880
# 21    https://journals.sagepub.com/doi/pdf/10.1177/0022242918816319
# 22    https://journals.sagepub.com/doi/pdf/10.1177/0022242918799699
# 23    https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0560
# 24    https://journals.sagepub.com/doi/pdf/10.1509/jm.09.0209
# 25    https://journals.sagepub.com/doi/pdf/10.1509/jm.10.0205
# 26    https://journals.sagepub.com/doi/pdf/10.1509/jm.09.0034
# 27    https://journals.sagepub.com/doi/pdf/10.1509/jm.10.0400
# 28    https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0400
# 29    https://journals.sagepub.com/doi/pdf/10.1509/jm.11.0428
# ...                                                       ...
# 1181  https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0311
# 1182  https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0113
# 1183  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.65
# 1184  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.3.074
# 1185  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.016
# 1186  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.4.1
# 1187  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.1
# 1188  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.080
# 1189  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.65
# 1190  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.6.19
# 1191  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.5.1
# 1192  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.80
# 1193  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.1.035
# 1194  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.3.74
# 1195  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.5.98
# 1196  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.4.15
# 1197  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.065
# 1198  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.3.052
# 1199  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.1.24
# 1200  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.1.35
# 1201  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.48
# 1202  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.6.019
# 1203  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.73.4.031
# 1204  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.001
# 1205  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.2.018
# 1206  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.4.001
# 1207  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.70.3.021
# 1208  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.74.3.065
# 1209  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.3.048
# 1210  https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.16
#
# [951 rows x 1 columns]
