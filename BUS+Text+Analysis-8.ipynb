# %%
#Chirag Narayanakere

from urllib.request import urlopen
import json
import pandas as pd
from pandas.io.json import json_normalize

#this is the url that we've already determined is safe and legal to scrape from
request = 'http://api.crossref.org/journals/00222429/works?filter=from-pub-date:2000-01-01&select=DOI&rows=1000'
request2 = 'http://api.crossref.org/journals/00222429/works?filter=from-pub-date:2000-01-01&select=DOI&rows=1000&offset=1000'

#here, we fetch the content from the url, using the requests library
response = urlopen(request, timeout=5)
response2 = urlopen(request2, timeout=5)

#here, we store the response (as a json object)
dois = response.read()
dois2 = response2.read()

#here, we read the json object into a dictionary
test = pd.read_json(dois)
test2 = pd.read_json(dois2)

#here, we convert the dictionary to a dataframe to allow for easier manipulation
master = pd.DataFrame.from_dict(test.iloc[1, 0])
master2 = pd.DataFrame.from_dict(test2.iloc[1, 0])

#combined dataframe
master_final = pd.concat([master, master2]).reset_index(drop=True)

#adding the base url to all the doi values
for i in range(0, len(master_final)):
    master_final['DOI'][i] = "https://journals.sagepub.com/doi/pdf/" + master_final['DOI'][i]

#show entire output
pd.set_option('display.max_colwidth', -1)

#final dataframe
master_final
# Out:
#                                                                    DOI
# 0     https://journals.sagepub.com/doi/pdf/10.1509/jm.75.2.109
# 1     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.2.114
# 2     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.3.171
# 3     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.66.2.102.18478
# 4     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.75.5.71
# 5     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.065
# 6     https://journals.sagepub.com/doi/pdf/10.1509/jmkg.67.1.29.18586
# 7     https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0211
# 8     https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0038
# 9     https://journals.sagepub.com/doi/pdf/10.1509/jm.15.0205
# 10    https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0457
# 11    https://journals.sagepub.com/doi/pdf/10.1509/jm.14.0305
# 12    https://journals.sagepub.com/doi/pdf/10.1509/jm.15.0413
# ...

# %% [markdown]
# ## Have to split up the status code checking into multiple parts so system does not time out

# %%
import requests

#holds indices of articles that do no exist anymore
errors = []

for i in range(0, 200):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors.append(i)

#print error links        
print(errors)
# Out:
# [18, 19, 28, 32, 33, 39, 54, 66, 102, 103, 104, 105, 106, 112, 129, 130, 131, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 145, 146, 147, 148, 157, 162, 163, 164, 176, 177, 180]

# %%
import requests

#holds indices of articles that do no exist anymore
errors1 = []

for i in range(200, 400):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors1.append(i)
        
print(errors1)
# Out:
# [224, 235, 241, 248, 249, 254, 258, 261, 270, 271, 272, 274, 278, 282, 284, 291, 294, 298, 299, 302, 324, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399]

# %%
import requests

#holds indices of articles that do no exist anymore
errors2 = []

for i in range(400, 600):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors2.append(i)

print(errors2)
# Out:
# [400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 523, 529, 530, 571, 592, 593]

# %%
import requests

#holds indices of articles that do no exist anymore
errors3 = []

for i in range(600, 800):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors3.append(i)

print(errors3)
# Out:
# [613, 652, 653, 656, 732, 735, 736]

# %%
import requests  

#holds indices of articles that do no exist anymore
errors4 = []

for i in range(800, 1000):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i]) 
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors4.append(i)

print(errors4)
# Out:
# [831, 835, 838, 840, 841, 847, 849, 852, 893, 897, 900, 901, 948, 949, 951, 952, 953, 954, 955, 956, 957, 958, 959, 960, 961, 962, 963, 964, 968, 969, 970, 971, 972, 973, 974, 978, 979, 980, 981, 982, 987, 990, 991, 992]

# %%
import requests

#holds indices of articles that do no exist anymore
errors5 = []

for i in range(1000, 1033):
    
    #checks to see link exists
    req = requests.get(master_final['DOI'][i])
    
    #if link doesn't exist, add index to errors
    if (req.status_code == 404):
        errors5.append(i)

print(errors5)
# Out:
# [1002, 1003, 1004, 1018, 1019]

# %%
#dropping rows where status code == 404
master_final_filtered = master_final.drop(errors)
master_final_filtered = master_final_filtered.drop(errors1)
master_final_filtered = master_final_filtered.drop(errors2)
master_final_filtered = master_final_filtered.drop(errors3)
master_final_filtered = master_final_filtered.drop(errors4)
master_final_filtered = master_final_filtered.drop(errors5)

#final dataframe post filtration
master_final_filtered = master_final_filtered.reset_index(drop=True)
master_final_filtered


master_final_filtered
# Out:
#                                                                   DOI
# 0    https://journals.sagepub.com/doi/pdf/10.1509/jm.75.2.109
# 1    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.2.114
# 2    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.71.3.171
# 3    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.66.2.102.18478
# 4    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.75.5.71
# 5    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.72.1.065
# 6    https://journals.sagepub.com/doi/pdf/10.1509/jmkg.67.1.29.18586
# 7    https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0211
# 8    https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0038
# 9    https://journals.sagepub.com/doi/pdf/10.1509/jm.15.0205
# 10   https://journals.sagepub.com/doi/pdf/10.1509/jm.16.0457
# 11   https://journals.sagepub.com/doi/pdf/10.1509/jm.14.0305
# 12   https://journals.sagepub.com/doi/pdf/10.1509/jm.15.0413
# 13   https://journals.sagepub.com/doi/pdf/10.1509/jmkg.2005.69.4.210
# ...

# %% [markdown]
# ### Read all info from articles and store in individual text files on Desktop

# %%
import io
import numpy as np
import requests
import pandas as pd
from PyPDF2 import PdfFileReader
import os
import time

#replace 3 with 942
for i in range(3):
    
    time.sleep(3)
    
    url = master_final_filtered['DOI'][i]

    r = requests.get(url)
    f = io.BytesIO(r.content)

    reader = PdfFileReader(f)
    number_of_pages = reader.getNumPages()

    filename = "Desktop/OUTPUTS/article:" + str(i) + ".txt"
    text_file = open(filename, "w")

    for page_number in range(number_of_pages):   
        page = reader.getPage(page_number)
        page_content = page.extractText()
        text_file.write(page_content)
                    
    text_file.close()
